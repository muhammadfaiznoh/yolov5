# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# # install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
# import torch

# from IPython.display import Image, clear_output  # to display images
# from utils.downloads import attempt_download  # to download models/datasets

# # clear_output()
# print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Setup complete. Using torch 2.0.1+cpu CPU

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="n8mV6peUiuhPmMeBxRRM")
# project = rf.workspace("muhammad-faiz-noh-glbe0").project("test-tube-jph4y")
# dataset = project.version(29).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (1.1.0)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: idna==2.10 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: python-dateutil in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: matplotlib in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: cycler==0.10.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: wget in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (3.2)
# Requirement already satisfied: supervision in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: six in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.0.3)
# Requirement already satisfied: requests-toolbelt in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: chardet==4.0.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.25.0)
# Requirement already satisfied: python-dotenv in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: colorama in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (4.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from requests->roboflow) (3.1.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in test-tube-29 to yolov5pytorch: 100% [457983 / 457983] bytes
# Extracting Dataset Version Zip to test-tube-29 in yolov5pytorch:: 100%|██████████| 30/30 [00:00<00:00, 1620.97it/s]

# %%
# # this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# UsageError: Line magic function `%cat` not found.

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open("./test-tube/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
print(num_classes)
# Out:
# 6

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
#%%time
#%cd /content/yolov5/
# !python train.py --img 600 --batch 16 --epochs 100 --data {"./test-tube"}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# train: weights='', cfg=./models/custom_yolov5s.yaml, data=./test-tube/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=600, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-195-gf313e45 Python-3.10.11 torch-2.0.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     29667  models.yolo.Detect                      [6, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7268579 parameters, 7268579 gradients
#
# WARNING  --img-size 600 must be multiple of max stride 32, updating to 608
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
#
# train: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\train\labels...:   0%|          | 0/24 [00:00<?, ?it/s]
# train: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\train\labels... 1 images, 0 backgrounds, 0 corrupt:   4%|▍         | 1/24 [00:10<04:04, 10.64s/it]
# train: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\train\labels... 24 images, 0 backgrounds, 0 corrupt: 100%|██████████| 24/24 [00:10<00:00,  2.25it/s]
# train: New cache created: C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\train\labels.cache
#
#   0%|          | 0/24 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100%|██████████| 24/24 [00:00<00:00, 791.65it/s]
#
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\valid\labels...:   0%|          | 0/2 [00:00<?, ?it/s]
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\valid\labels... 1 images, 0 backgrounds, 0 corrupt:  50%|█████     | 1/2 [00:10<00:10, 10.03s/it]
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\valid\labels... 2 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2/2 [00:10<00:00,  5.02s/it]
# val: New cache created: C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube\valid\labels.cache
#
#   0%|          | 0/2 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100%|██████████| 2/2 [00:00<00:00, 163.37it/s]
#
# AutoAnchor: 4.42 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\yolov5s_results22\labels.jpg...
# Image sizes 608 train, 608 val
# Using 8 dataloader workers
# Logging results to runs\train\yolov5s_results22
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#        0/99         0G     0.1178      0.264    0.05232       1044        608:   0%|          | 0/2 [00:24<?, ?it/s]
#        0/99         0G     0.1178      0.264    0.05232       1044        608:  50%|█████     | 1/2 [00:24<00:24, 24.78s/it]
#        0/99         0G     0.1191     0.1727    0.05236        270        608:  50%|█████     | 1/2 [00:33<00:24, 24.78s/it]
#        0/99         0G     0.1191     0.1727    0.05236        270        608: 100%|██████████| 2/2 [00:33<00:00, 15.49s/it]
#        0/99         0G     0.1191     0.1727    0.05236        270        608: 100%|██████████| 2/2 [00:33<00:00, 16.88s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
#                    all          2        132          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.51s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.51s/it]
#                    all          2        132     0.0748       0.18     0.0985     0.0229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#       95/99         0G     0.1015     0.1251    0.04084        883        608:   0%|          | 0/2 [00:17<?, ?it/s]
#       95/99         0G     0.1015     0.1251    0.04084        883        608:  50%|█████     | 1/2 [00:17<00:17, 17.16s/it]
#       95/99         0G     0.0949     0.1456    0.04307        543        608:  50%|█████     | 1/2 [00:25<00:17, 17.16s/it]
#       95/99         0G     0.0949     0.1456    0.04307        543        608: 100%|██████████| 2/2 [00:25<00:00, 12.12s/it]
#       95/99         0G     0.0949     0.1456    0.04307        543        608: 100%|██████████| 2/2 [00:25<00:00, 12.88s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
#                    all          2        132     0.0741       0.18     0.0965      0.021
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#       96/99         0G    0.09624     0.1409    0.03853        764        608:   0%|          | 0/2 [00:17<?, ?it/s]
#       96/99         0G    0.09624     0.1409    0.03853        764        608:  50%|█████     | 1/2 [00:17<00:17, 17.39s/it]
#       96/99         0G    0.09611     0.1272    0.04015        501        608:  50%|█████     | 1/2 [00:26<00:17, 17.39s/it]
#       96/99         0G    0.09611     0.1272    0.04015        501        608: 100%|██████████| 2/2 [00:26<00:00, 12.26s/it]
#       96/99         0G    0.09611     0.1272    0.04015        501        608: 100%|██████████| 2/2 [00:26<00:00, 13.03s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
#                    all          2        132     0.0741       0.18     0.0965      0.021
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#       97/99         0G    0.09238     0.1384    0.04259       1010        608:   0%|          | 0/2 [00:22<?, ?it/s]
#       97/99         0G    0.09238     0.1384    0.04259       1010        608:  50%|█████     | 1/2 [00:22<00:22, 22.68s/it]
#       97/99         0G    0.09298     0.1432    0.04036        354        608:  50%|█████     | 1/2 [00:32<00:22, 22.68s/it]
#       97/99         0G    0.09298     0.1432    0.04036        354        608: 100%|██████████| 2/2 [00:32<00:00, 15.33s/it]
#       97/99         0G    0.09298     0.1432    0.04036        354        608: 100%|██████████| 2/2 [00:32<00:00, 16.43s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.86s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.87s/it]
#                    all          2        132     0.0694      0.172     0.0835     0.0205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#       98/99         0G    0.09687     0.1321    0.03881        703        608:   0%|          | 0/2 [00:19<?, ?it/s]
#       98/99         0G    0.09687     0.1321    0.03881        703        608:  50%|█████     | 1/2 [00:19<00:19, 19.45s/it]
#       98/99         0G    0.09888      0.152    0.03932        498        608:  50%|█████     | 1/2 [00:28<00:19, 19.45s/it]
#       98/99         0G    0.09888      0.152    0.03932        498        608: 100%|██████████| 2/2 [00:28<00:00, 13.38s/it]
#       98/99         0G    0.09888      0.152    0.03932        498        608: 100%|██████████| 2/2 [00:28<00:00, 14.29s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
#                    all          2        132     0.0694      0.172     0.0835     0.0205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#       99/99         0G    0.09568    0.07957    0.04312        258        608:   0%|          | 0/2 [00:19<?, ?it/s]
#       99/99         0G    0.09568    0.07957    0.04312        258        608:  50%|█████     | 1/2 [00:19<00:19, 19.38s/it]
#       99/99         0G    0.09596     0.1101    0.04122        400        608:  50%|█████     | 1/2 [00:28<00:19, 19.38s/it]
#       99/99         0G    0.09596     0.1101    0.04122        400        608: 100%|██████████| 2/2 [00:28<00:00, 13.36s/it]
#       99/99         0G    0.09596     0.1101    0.04122        400        608: 100%|██████████| 2/2 [00:28<00:00, 14.26s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
#                    all          2        132     0.0696      0.172     0.0829     0.0205
#
# 100 epochs completed in 0.718 hours.
# Optimizer stripped from runs\train\yolov5s_results22\weights\last.pt, 14.9MB
# Optimizer stripped from runs\train\yolov5s_results22\weights\best.pt, 14.9MB
#
# Validating runs\train\yolov5s_results22\weights\best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7260003 parameters, 0 gradients
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]WARNING  NMS time limit 0.600s exceeded
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
#                    all          2        132      0.066      0.155     0.0879     0.0276
#              20-39loss          2         76      0.191        0.5       0.35      0.107
#              40-59loss          2         10          0          0          0          0
#                blocked          2         40      0.139      0.275     0.0893     0.0314
#                loss-60          2          2          0          0          0          0
#                plugged          2          4          0          0          0          0
# Results saved to runs\train\yolov5s_results22

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# !python detect.py --weights ./runs/train/yolov5s_results22/weights/last.pt --img 600 --conf 0.5 --source images
# Out:
# detect: weights=['./runs/train/yolov5s_results22/weights/last.pt'], source=images, data=data\coco128.yaml, imgsz=[600, 600], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-195-gf313e45 Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7260003 parameters, 0 gradients
# WARNING  --img-size [600, 600] must be multiple of max stride 32, updating to [608, 608]
# image 1/2 C:\Users\faiz.noh\yolov5\tube_detection\yolov5\images\test1.jpeg: 608x416 31 20-39losss, 146.0ms
# image 2/2 C:\Users\faiz.noh\yolov5\tube_detection\yolov5\images\test2.jpeg: 608x512 103 20-39losss, 180.8ms
# Speed: 1.0ms pre-process, 163.4ms inference, 2.0ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs\detect\exp3

# %%
# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason...
# from utils.plots import plot_results  # plot results.txt as results.png
# Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # first, display our ground truth data
#       2 print("GROUND TRUTH TRAINING DATA:")
# ----> 3 Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg'

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/

# %%
# %ls runs/train/yolov5s_results/weights

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source ../test/images

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
