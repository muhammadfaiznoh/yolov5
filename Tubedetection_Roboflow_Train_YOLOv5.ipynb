# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Setup complete. Using torch 2.0.1+cpu CPU

# %% [markdown]
# # Download Correctly Formatted Custom Dataset
#
# We'll download our dataset from Roboflow. Use the "**YOLOv5 PyTorch**" export format. Note that the Ultralytics implementation calls for a YAML file defining where your training and test data is. The Roboflow export also writes this format for us.
#
# To get your data into Roboflow, follow the [Getting Started Guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![YOLOv5 PyTorch export](https://i.imgur.com/5vr9G2u.png)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="n8mV6peUiuhPmMeBxRRM")
project = rf.workspace("muhammad-faiz-noh-glbe0").project("test-tube-jph4y")
dataset = project.version(29).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (1.1.0)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: idna==2.10 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: python-dateutil in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: matplotlib in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: cycler==0.10.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: wget in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (3.2)
# Requirement already satisfied: supervision in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: six in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.0.3)
# Requirement already satisfied: requests-toolbelt in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: chardet==4.0.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.25.0)
# Requirement already satisfied: python-dotenv in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: colorama in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from matplotlib->roboflow) (4.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\faiz.noh\yolov5\tube_detection\lib\site-packages (from requests->roboflow) (3.1.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in test-tube-29 to yolov5pytorch: 100% [457983 / 457983] bytes
# Extracting Dataset Version Zip to test-tube-29 in yolov5pytorch:: 100%|██████████| 30/30 [00:00<00:00, 1620.97it/s]

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {dataset.location}/data.yaml
# Out:
# UsageError: Line magic function `%cat` not found.

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open("./test-tube-16/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
print(num_classes)
# Out:
# 6

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
#%%time
#%cd /content/yolov5/
# !python train.py --img 700 --batch 16 --epochs 100 --data {"./test-tube-29"}/data.yaml --cfg ./models/yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# train: weights='', cfg=./models/yolov5s.yaml, data=./test-tube-29/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=600, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 8 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-185-g2334aa7 Python-3.10.11 torch-2.0.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     29667  models.yolo.Detect                      [6, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7035811 parameters, 7035811 gradients, 16.0 GFLOPs
#
# WARNING  --img-size 600 must be multiple of max stride 32, updating to 608
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\train\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
# train: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\train\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6/6 [00:00<?, ?it/s]
#
#   0%|          | 0/6 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100%|██████████| 6/6 [00:00<00:00, 363.55it/s]
#
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\valid\labels...:   0%|          | 0/2 [00:00<?, ?it/s]
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\valid\labels... 1 images, 0 backgrounds, 0 corrupt:  50%|█████     | 1/2 [00:16<00:16, 16.05s/it]
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\valid\labels... 2 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2/2 [00:16<00:00,  6.72s/it]
# val: Scanning C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\valid\labels... 2 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2/2 [00:16<00:00,  8.12s/it]
# val: New cache created: C:\Users\faiz.noh\yolov5\tube_detection\yolov5\test-tube-29\valid\labels.cache
#
#   0%|          | 0/2 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100%|██████████| 2/2 [00:00<00:00, 198.23it/s]
#
# AutoAnchor: 4.01 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Plotting labels to runs\train\yolov5s_results16\labels.jpg...
# Image sizes 608 train, 608 val
# Using 6 dataloader workers
# Logging results to runs\train\yolov5s_results16
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        0/99         0G     0.1388     0.1775    0.05322        848        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        0/99         0G     0.1388     0.1775    0.05322        848        608: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
#        0/99         0G     0.1388     0.1775    0.05322        848        608: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        1/99         0G     0.1301     0.2168    0.05276        529        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        1/99         0G     0.1301     0.2168    0.05276        529        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#        1/99         0G     0.1301     0.2168    0.05276        529        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        2/99         0G     0.1271      0.108    0.05342        394        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        2/99         0G     0.1271      0.108    0.05342        394        608: 100%|██████████| 1/1 [00:05<00:00,  5.98s/it]
#        2/99         0G     0.1271      0.108    0.05342        394        608: 100%|██████████| 1/1 [00:05<00:00,  5.98s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        3/99         0G     0.1276     0.2606    0.05305        643        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        3/99         0G     0.1276     0.2606    0.05305        643        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#        3/99         0G     0.1276     0.2606    0.05305        643        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        4/99         0G     0.1342     0.2788    0.05258        699        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        4/99         0G     0.1342     0.2788    0.05258        699        608: 100%|██████████| 1/1 [00:05<00:00,  5.33s/it]
#        4/99         0G     0.1342     0.2788    0.05258        699        608: 100%|██████████| 1/1 [00:05<00:00,  5.33s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        5/99         0G     0.1331     0.2263     0.0538        586        608:   0%|          | 0/1 [00:07<?, ?it/s]
#        5/99         0G     0.1331     0.2263     0.0538        586        608: 100%|██████████| 1/1 [00:07<00:00,  7.05s/it]
#        5/99         0G     0.1331     0.2263     0.0538        586        608: 100%|██████████| 1/1 [00:07<00:00,  7.05s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        6/99         0G     0.1303     0.2662    0.05265        622        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        6/99         0G     0.1303     0.2662    0.05265        622        608: 100%|██████████| 1/1 [00:05<00:00,  5.89s/it]
#        6/99         0G     0.1303     0.2662    0.05265        622        608: 100%|██████████| 1/1 [00:05<00:00,  5.89s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        7/99         0G     0.1398     0.1681    0.05425        526        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        7/99         0G     0.1398     0.1681    0.05425        526        608: 100%|██████████| 1/1 [00:05<00:00,  5.19s/it]
#        7/99         0G     0.1398     0.1681    0.05425        526        608: 100%|██████████| 1/1 [00:05<00:00,  5.19s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        8/99         0G      0.126      0.233    0.05293        498        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        8/99         0G      0.126      0.233    0.05293        498        608: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
#        8/99         0G      0.126      0.233    0.05293        498        608: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#        9/99         0G     0.1311     0.2531    0.05267        538        608:   0%|          | 0/1 [00:05<?, ?it/s]
#        9/99         0G     0.1311     0.2531    0.05267        538        608: 100%|██████████| 1/1 [00:05<00:00,  5.31s/it]
#        9/99         0G     0.1311     0.2531    0.05267        538        608: 100%|██████████| 1/1 [00:05<00:00,  5.31s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       10/99         0G     0.1248     0.3452    0.05268        511        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       10/99         0G     0.1248     0.3452    0.05268        511        608: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
#       10/99         0G     0.1248     0.3452    0.05268        511        608: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       11/99         0G     0.1289      0.287    0.05281        902        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       11/99         0G     0.1289      0.287    0.05281        902        608: 100%|██████████| 1/1 [00:06<00:00,  6.04s/it]
#       11/99         0G     0.1289      0.287    0.05281        902        608: 100%|██████████| 1/1 [00:06<00:00,  6.04s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       12/99         0G     0.1252     0.2535    0.05261        550        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       12/99         0G     0.1252     0.2535    0.05261        550        608: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
#       12/99         0G     0.1252     0.2535    0.05261        550        608: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       13/99         0G    0.08806     0.2379    0.03491        673        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       13/99         0G    0.08806     0.2379    0.03491        673        608: 100%|██████████| 1/1 [00:06<00:00,  6.21s/it]
#       13/99         0G    0.08806     0.2379    0.03491        673        608: 100%|██████████| 1/1 [00:06<00:00,  6.21s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       14/99         0G     0.1276      0.262    0.05184        634        608:   0%|          | 0/1 [00:07<?, ?it/s]
#       14/99         0G     0.1276      0.262    0.05184        634        608: 100%|██████████| 1/1 [00:07<00:00,  7.81s/it]
#       14/99         0G     0.1276      0.262    0.05184        634        608: 100%|██████████| 1/1 [00:07<00:00,  7.81s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       15/99         0G      0.123     0.2959    0.05211        378        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       15/99         0G      0.123     0.2959    0.05211        378        608: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#       15/99         0G      0.123     0.2959    0.05211        378        608: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       16/99         0G     0.1256     0.2777    0.05187        616        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       16/99         0G     0.1256     0.2777    0.05187        616        608: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
#       16/99         0G     0.1256     0.2777    0.05187        616        608: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       17/99         0G    0.08683     0.2875    0.03493        948        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       17/99         0G    0.08683     0.2875    0.03493        948        608: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
#       17/99         0G    0.08683     0.2875    0.03493        948        608: 100%|██████████| 1/1 [00:05<00:00,  5.28s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       18/99         0G     0.1255     0.2601    0.05195        672        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       18/99         0G     0.1255     0.2601    0.05195        672        608: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
#       18/99         0G     0.1255     0.2601    0.05195        672        608: 100%|██████████| 1/1 [00:05<00:00,  5.71s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       19/99         0G     0.1287     0.2164    0.05015        494        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       19/99         0G     0.1287     0.2164    0.05015        494        608: 100%|██████████| 1/1 [00:05<00:00,  5.36s/it]
#       19/99         0G     0.1287     0.2164    0.05015        494        608: 100%|██████████| 1/1 [00:05<00:00,  5.36s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       20/99         0G     0.1304      0.354    0.05254        762        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       20/99         0G     0.1304      0.354    0.05254        762        608: 100%|██████████| 1/1 [00:05<00:00,  5.92s/it]
#       20/99         0G     0.1304      0.354    0.05254        762        608: 100%|██████████| 1/1 [00:05<00:00,  5.92s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       21/99         0G     0.1282     0.2846    0.05144        626        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       21/99         0G     0.1282     0.2846    0.05144        626        608: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#       21/99         0G     0.1282     0.2846    0.05144        626        608: 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       22/99         0G     0.1285     0.3543    0.04944        746        608:   0%|          | 0/1 [00:08<?, ?it/s]
#       22/99         0G     0.1285     0.3543    0.04944        746        608: 100%|██████████| 1/1 [00:08<00:00,  8.38s/it]
#       22/99         0G     0.1285     0.3543    0.04944        746        608: 100%|██████████| 1/1 [00:08<00:00,  8.38s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       23/99         0G     0.1276     0.2166    0.04896        402        608:   0%|          | 0/1 [00:04<?, ?it/s]
#       23/99         0G     0.1276     0.2166    0.04896        402        608: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
#       23/99         0G     0.1276     0.2166    0.04896        402        608: 100%|██████████| 1/1 [00:04<00:00,  4.91s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       24/99         0G    0.08649     0.2452    0.03437        702        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       24/99         0G    0.08649     0.2452    0.03437        702        608: 100%|██████████| 1/1 [00:05<00:00,  5.41s/it]
#       24/99         0G    0.08649     0.2452    0.03437        702        608: 100%|██████████| 1/1 [00:05<00:00,  5.41s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       25/99         0G     0.1249      0.302    0.05208        885        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       25/99         0G     0.1249      0.302    0.05208        885        608: 100%|██████████| 1/1 [00:05<00:00,  5.18s/it]
#       25/99         0G     0.1249      0.302    0.05208        885        608: 100%|██████████| 1/1 [00:05<00:00,  5.18s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       26/99         0G     0.1212      0.233    0.05265        478        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       26/99         0G     0.1212      0.233    0.05265        478        608: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
#       26/99         0G     0.1212      0.233    0.05265        478        608: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       27/99         0G     0.1238     0.2725    0.05024        579        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       27/99         0G     0.1238     0.2725    0.05024        579        608: 100%|██████████| 1/1 [00:05<00:00,  5.57s/it]
#       27/99         0G     0.1238     0.2725    0.05024        579        608: 100%|██████████| 1/1 [00:05<00:00,  5.57s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       28/99         0G     0.1275      0.236    0.04935        465        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       28/99         0G     0.1275      0.236    0.04935        465        608: 100%|██████████| 1/1 [00:05<00:00,  5.81s/it]
#       28/99         0G     0.1275      0.236    0.04935        465        608: 100%|██████████| 1/1 [00:05<00:00,  5.81s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       29/99         0G      0.121     0.2966    0.05168        800        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       29/99         0G      0.121     0.2966    0.05168        800        608: 100%|██████████| 1/1 [00:05<00:00,  5.78s/it]
#       29/99         0G      0.121     0.2966    0.05168        800        608: 100%|██████████| 1/1 [00:05<00:00,  5.78s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       30/99         0G     0.1208     0.2597    0.05252        460        608:   0%|          | 0/1 [00:08<?, ?it/s]
#       30/99         0G     0.1208     0.2597    0.05252        460        608: 100%|██████████| 1/1 [00:08<00:00,  8.67s/it]
#       30/99         0G     0.1208     0.2597    0.05252        460        608: 100%|██████████| 1/1 [00:08<00:00,  8.67s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       31/99         0G     0.1258     0.1766    0.05035        334        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       31/99         0G     0.1258     0.1766    0.05035        334        608: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
#       31/99         0G     0.1258     0.1766    0.05035        334        608: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       32/99         0G     0.1309     0.1929     0.0478        481        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       32/99         0G     0.1309     0.1929     0.0478        481        608: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
#       32/99         0G     0.1309     0.1929     0.0478        481        608: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       33/99         0G      0.125     0.2623    0.05091        694        608:   0%|          | 0/1 [00:04<?, ?it/s]
#       33/99         0G      0.125     0.2623    0.05091        694        608: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
#       33/99         0G      0.125     0.2623    0.05091        694        608: 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       34/99         0G       0.12      0.238    0.04985        684        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       34/99         0G       0.12      0.238    0.04985        684        608: 100%|██████████| 1/1 [00:06<00:00,  6.03s/it]
#       34/99         0G       0.12      0.238    0.04985        684        608: 100%|██████████| 1/1 [00:06<00:00,  6.03s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       35/99         0G     0.1215     0.2918    0.05135        635        608:   0%|          | 0/1 [00:04<?, ?it/s]
#       35/99         0G     0.1215     0.2918    0.05135        635        608: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
#       35/99         0G     0.1215     0.2918    0.05135        635        608: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       36/99         0G     0.1168     0.2509    0.05199        430        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       36/99         0G     0.1168     0.2509    0.05199        430        608: 100%|██████████| 1/1 [00:05<00:00,  5.73s/it]
#       36/99         0G     0.1168     0.2509    0.05199        430        608: 100%|██████████| 1/1 [00:05<00:00,  5.73s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       37/99         0G     0.1286     0.1644    0.04848        439        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       37/99         0G     0.1286     0.1644    0.04848        439        608: 100%|██████████| 1/1 [00:05<00:00,  5.11s/it]
#       37/99         0G     0.1286     0.1644    0.04848        439        608: 100%|██████████| 1/1 [00:05<00:00,  5.11s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       38/99         0G     0.1204     0.2919    0.04974        497        608:   0%|          | 0/1 [00:07<?, ?it/s]
#       38/99         0G     0.1204     0.2919    0.04974        497        608: 100%|██████████| 1/1 [00:07<00:00,  7.58s/it]
#       38/99         0G     0.1204     0.2919    0.04974        497        608: 100%|██████████| 1/1 [00:07<00:00,  7.58s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       39/99         0G     0.1247     0.3525    0.04845        646        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       39/99         0G     0.1247     0.3525    0.04845        646        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#       39/99         0G     0.1247     0.3525    0.04845        646        608: 100%|██████████| 1/1 [00:05<00:00,  5.56s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       40/99         0G     0.1251     0.1985    0.04727        474        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       40/99         0G     0.1251     0.1985    0.04727        474        608: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
#       40/99         0G     0.1251     0.1985    0.04727        474        608: 100%|██████████| 1/1 [00:05<00:00,  5.12s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       41/99         0G     0.1238     0.3094    0.05175        663        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       41/99         0G     0.1238     0.3094    0.05175        663        608: 100%|██████████| 1/1 [00:05<00:00,  5.37s/it]
#       41/99         0G     0.1238     0.3094    0.05175        663        608: 100%|██████████| 1/1 [00:05<00:00,  5.37s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       42/99         0G     0.1325     0.2291    0.05293        737        608:   0%|          | 0/1 [00:05<?, ?it/s]
#       42/99         0G     0.1325     0.2291    0.05293        737        608: 100%|██████████| 1/1 [00:05<00:00,  5.34s/it]
#       42/99         0G     0.1325     0.2291    0.05293        737        608: 100%|██████████| 1/1 [00:05<00:00,  5.34s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# ...
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       85/99         0G     0.1242     0.1967     0.0457        442        608:   0%|          | 0/1 [00:09<?, ?it/s]
#       85/99         0G     0.1242     0.1967     0.0457        442        608: 100%|██████████| 1/1 [00:09<00:00,  9.13s/it]
#       85/99         0G     0.1242     0.1967     0.0457        442        608: 100%|██████████| 1/1 [00:09<00:00,  9.13s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       86/99         0G     0.1214     0.2659    0.04746        610        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       86/99         0G     0.1214     0.2659    0.04746        610        608: 100%|██████████| 1/1 [00:06<00:00,  6.43s/it]
#       86/99         0G     0.1214     0.2659    0.04746        610        608: 100%|██████████| 1/1 [00:06<00:00,  6.43s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       87/99         0G     0.1223     0.2522    0.04667        531        608:   0%|          | 0/1 [00:07<?, ?it/s]
#       87/99         0G     0.1223     0.2522    0.04667        531        608: 100%|██████████| 1/1 [00:07<00:00,  7.00s/it]
#       87/99         0G     0.1223     0.2522    0.04667        531        608: 100%|██████████| 1/1 [00:07<00:00,  7.00s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.70s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       88/99         0G     0.1186     0.3593       0.05        732        608:   0%|          | 0/1 [00:09<?, ?it/s]
#       88/99         0G     0.1186     0.3593       0.05        732        608: 100%|██████████| 1/1 [00:09<00:00,  9.46s/it]
#       88/99         0G     0.1186     0.3593       0.05        732        608: 100%|██████████| 1/1 [00:09<00:00,  9.46s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       89/99         0G     0.1176     0.2535    0.05013        553        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       89/99         0G     0.1176     0.2535    0.05013        553        608: 100%|██████████| 1/1 [00:06<00:00,  6.16s/it]
#       89/99         0G     0.1176     0.2535    0.05013        553        608: 100%|██████████| 1/1 [00:06<00:00,  6.16s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       90/99         0G     0.1188      0.472    0.04887        986        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       90/99         0G     0.1188      0.472    0.04887        986        608: 100%|██████████| 1/1 [00:06<00:00,  6.77s/it]
#       90/99         0G     0.1188      0.472    0.04887        986        608: 100%|██████████| 1/1 [00:06<00:00,  6.77s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       91/99         0G     0.1289     0.2344    0.05004        996        608:   0%|          | 0/1 [00:08<?, ?it/s]
#       91/99         0G     0.1289     0.2344    0.05004        996        608: 100%|██████████| 1/1 [00:08<00:00,  8.86s/it]
#       91/99         0G     0.1289     0.2344    0.05004        996        608: 100%|██████████| 1/1 [00:08<00:00,  8.86s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       92/99         0G     0.1234     0.2087    0.04602        523        608:   0%|          | 0/1 [00:07<?, ?it/s]
#       92/99         0G     0.1234     0.2087    0.04602        523        608: 100%|██████████| 1/1 [00:07<00:00,  7.42s/it]
#       92/99         0G     0.1234     0.2087    0.04602        523        608: 100%|██████████| 1/1 [00:07<00:00,  7.42s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       93/99         0G     0.1245     0.2102    0.04662        640        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       93/99         0G     0.1245     0.2102    0.04662        640        608: 100%|██████████| 1/1 [00:06<00:00,  6.64s/it]
#       93/99         0G     0.1245     0.2102    0.04662        640        608: 100%|██████████| 1/1 [00:06<00:00,  6.64s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       94/99         0G     0.1167     0.2198    0.05003        910        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       94/99         0G     0.1167     0.2198    0.05003        910        608: 100%|██████████| 1/1 [00:06<00:00,  6.79s/it]
#       94/99         0G     0.1167     0.2198    0.05003        910        608: 100%|██████████| 1/1 [00:06<00:00,  6.79s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       95/99         0G     0.1217     0.2658    0.04693        668        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       95/99         0G     0.1217     0.2658    0.04693        668        608: 100%|██████████| 1/1 [00:06<00:00,  6.88s/it]
#       95/99         0G     0.1217     0.2658    0.04693        668        608: 100%|██████████| 1/1 [00:06<00:00,  6.88s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       96/99         0G     0.1243     0.1477     0.0471        517        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       96/99         0G     0.1243     0.1477     0.0471        517        608: 100%|██████████| 1/1 [00:06<00:00,  6.74s/it]
#       96/99         0G     0.1243     0.1477     0.0471        517        608: 100%|██████████| 1/1 [00:06<00:00,  6.74s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       97/99         0G     0.1294     0.1579    0.04446        754        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       97/99         0G     0.1294     0.1579    0.04446        754        608: 100%|██████████| 1/1 [00:06<00:00,  6.99s/it]
#       97/99         0G     0.1294     0.1579    0.04446        754        608: 100%|██████████| 1/1 [00:06<00:00,  6.99s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.70s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       98/99         0G     0.1242     0.1478     0.0502        511        608:   0%|          | 0/1 [00:09<?, ?it/s]
#       98/99         0G     0.1242     0.1478     0.0502        511        608: 100%|██████████| 1/1 [00:09<00:00,  9.32s/it]
#       98/99         0G     0.1242     0.1478     0.0502        511        608: 100%|██████████| 1/1 [00:09<00:00,  9.32s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                    all          2        287          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#       99/99         0G     0.1315     0.1699    0.05133        529        608:   0%|          | 0/1 [00:06<?, ?it/s]
#       99/99         0G     0.1315     0.1699    0.05133        529        608: 100%|██████████| 1/1 [00:06<00:00,  6.43s/it]
#       99/99         0G     0.1315     0.1699    0.05133        529        608: 100%|██████████| 1/1 [00:06<00:00,  6.43s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
#                    all          2        287          0          0          0          0
#
# 100 epochs completed in 0.217 hours.
# Optimizer stripped from runs\train\yolov5s_results16\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\yolov5s_results16\weights\best.pt, 14.4MB
#
# Validating runs\train\yolov5s_results16\weights\best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
#                    all          2        287          0          0          0          0
# Results saved to runs\train\yolov5s_results16

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# !python detect.py --weights ./runs/train/yolov5s_results/weights/best.pt --img 600 --conf 0.4 --source images
# Out:
# detect: weights=['./runs/train/yolov5s_results/weights/best.pt'], source=images, data=data\coco128.yaml, imgsz=[600, 600], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-185-g2334aa7 Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [600, 600] must be multiple of max stride 32, updating to [608, 608]
# image 1/2 C:\Users\faiz.noh\yolov5\tube_detection\yolov5\images\test1.jpeg: 608x416 (no detections), 181.4ms
# image 2/2 C:\Users\faiz.noh\yolov5\tube_detection\yolov5\images\test2.jpeg: 608x512 (no detections), 191.3ms
# Speed: 1.0ms pre-process, 186.4ms inference, 1.0ms NMS per image at shape (1, 3, 608, 608)
# Results saved to runs\detect\exp16

# %%
# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason...
# from utils.plots import plot_results  # plot results.txt as results.png
# Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # first, display our ground truth data
#       2 print("GROUND TRUTH TRAINING DATA:")
# ----> 3 Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File c:\Users\faiz.noh\yolov5\tube_detection\lib\site-packages\IPython\core\display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg'

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/

# %%
# %ls runs/train/yolov5s_results/weights

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source ../test/images

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cp /content/yolov5/runs/train/yolov5s_results/weights/best.pt /content/gdrive/My\ Drive

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
